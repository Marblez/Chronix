# %%
import pyrebase
import numpy 
import matplotlib.pyplot as plt

config = {
    "apiKey": "AIzaSyAYTc8g4A6AuWxEsZv8ETebkeiseS6sRVY",
    "authDomain": "cryptodata-ab1e2.firebaseapp.com",
    "databaseURL": "https://cryptodata-ab1e2.firebaseio.com",
    "projectId": "cryptodata-ab1e2",
    "storageBucket": "cryptodata-ab1e2.appspot.com",
    "messagingSenderId": "518294849950",
    "appId": "1:518294849950:web:7ef53f8bc67b110383ae8f"
  };

strategy_id = "1591623256"

# %%
def OrdDictToList(ord_dict):
    vals = []
    for value in ord_dict.values():
        vals.append(value)
    return list(map(float, vals))

# %%
firebase = pyrebase.initialize_app(config)
db = firebase.database()
portfolio_data = db.child(strategy_id + "/portfolio").get()

# %%
portfolio_value = OrdDictToList(portfolio_data.val())

# %%
fig = plt.figure()
plt.plot(portfolio_value)
fig.suptitle('Portfolio Value', fontsize=20)
fig2 = plt.figure()
plt.plot(portfolio_value)
fig2.suptitle('Asset Value', fontsize=20)
# Out:
# Text(0.5, 0.98, 'Asset Value')
