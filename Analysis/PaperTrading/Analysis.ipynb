# %%
import pyrebase
import numpy 
import matplotlib.pyplot as plt

config = {
    "apiKey": "AIzaSyACWoPHw74B89ZshAhezbKFGr9q0XWAPOw",
    "authDomain": "tach-1ff2f.firebaseapp.com",
    "databaseURL": "https://tach-1ff2f.firebaseio.com",
    "projectId": "tach-1ff2f",
    "storageBucket": "tach-1ff2f.appspot.com",
    "messagingSenderId": "954930106547",
    "appId": "1:954930106547:web:aaab9d293d55d41724e0c6"
  };

strategy_id = "hmm1:ETHUSD"

# %%
firebase = pyrebase.initialize_app(config)
db = firebase.database()
portfolio_data = (db.child(strategy_id).get()).val()

# %%
balances = []
holdings = []
prices = []
values = []
for value in portfolio_data:
    balances.append(portfolio_data[value]['Balance'])
    holdings.append(portfolio_data[value]['Holdings'])
    prices.append(portfolio_data[value]['Price'])
    values.append(portfolio_data[value]['Value'])

# %%
fig = plt.figure()
plt.plot(prices)
fig.suptitle('Asset Price', fontsize=20)
fig2 = plt.figure()
plt.plot(values)
fig2.suptitle('Portfolio Value', fontsize=20)
# Out:
# Text(0.5, 0.98, 'Portfolio Value')

# %%
len(balances)
# Out:
# 216
